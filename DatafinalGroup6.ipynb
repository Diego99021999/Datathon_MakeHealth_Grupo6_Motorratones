# %%
import pandas as pd
import os
import seaborn as sns
import matplotlib.pyplot as plt

# %%
os.getcwd()
# Out:
# '/Users/juan/Downloads'

# %%
df = pd.read_excel('/Users/juan/Downloads/covid_latam(raw).xlsx')

# %%
df
# Out:
#       iso_code      continent             location       date  total_cases  \
# 0          ATG  North America  Antigua and Barbuda 2020-03-13          1.0
# 1          ATG  North America  Antigua and Barbuda 2020-03-14          1.0
# 2          ATG  North America  Antigua and Barbuda 2020-03-15          1.0
# 3          ATG  North America  Antigua and Barbuda 2020-03-16          1.0
# 4          ATG  North America  Antigua and Barbuda 2020-03-17          1.0
# ...        ...            ...                  ...        ...          ...
# 25963      VEN  South America            Venezuela 2022-05-22     523343.0
# 25964      VEN  South America            Venezuela 2022-05-23     523377.0
# 25965      VEN  South America            Venezuela 2022-05-24     523411.0
# 25966      VEN  South America            Venezuela 2022-05-25     523411.0
# 25967      VEN  South America            Venezuela 2022-05-26     523444.0
#
#        new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# ...

# %%
df[["date","new_deaths"]]
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(15,8))
sns.lineplot(data= df, x= "date", y="new_deaths")
# Out:
# <AxesSubplot:xlabel='date', ylabel='new_deaths'>

# %%
val_limite = df.new_deaths.mean()
# Out:
# 69.18888935056302

# %%
df.groupby('iso_code').mean()['new_deaths']
# Out:
# iso_code
# ARG    159.832506
# ATG      0.176923
# BHS      1.030534
# BLZ      0.874198
# BOL     27.814956
# BRA    833.871089
# BRB      0.567775
# CHL     57.452711
# COL    175.695980
# CRI     10.658720
# CUB     10.675845
# DMA      0.233813
# DOM      5.464419
# ECU     28.658354
# GRD      0.444008
# GTM     22.534332
# GUY      1.528536
# HND     13.915190
# HTI      1.178295
# JAM      3.809762
# LCA      0.657194
# MEX    400.659521
# NIC      0.300885
# PAN     10.209418
# PER    264.017284
# PRY     23.665414
# SLV      5.249047
# SUR      1.710459
# TTO      4.920555
# URY      9.171320
# VCT      0.213280
# VEN      7.245570
# Name: new_deaths, dtype: float64

# %%
df[df.iso_code=='BRB'].new_deaths.mean()
# Out:
# 0.5677749360613811

# %%
Agrup = df.groupby('iso_code').mean()['new_deaths']

# %%
Malos = Agrup > 65

# %%
Malos[Malos == True]
# Out:
# iso_code
# ARG    True
# BRA    True
# COL    True
# MEX    True
# PER    True
# Name: new_deaths, dtype: bool

# %%
df[['iso_code', 'new_deaths']]
# Out:
#       iso_code  new_deaths
# 0          ATG         NaN
# 1          ATG         NaN
# 2          ATG         NaN
# 3          ATG         NaN
# 4          ATG         NaN
# ...        ...         ...
# 25963      VEN         0.0
# 25964      VEN         0.0
# 25965      VEN         1.0
# 25966      VEN         0.0
# 25967      VEN         1.0
#
# [25968 rows x 2 columns]

# %%
df.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'total_tests', 'new_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'total_boosters',
# ...

# %%
df.new_deaths.max()
# Out:
# 4148.0

# %%
df.new_deaths.min()
# Out:
# 0.0

# %%
plt.figure(figsize=(15,8))
sns.lineplot(data= df, x= "date", y="new_deaths") "iso_code"
# Out:
#   File "/var/folders/3z/xmq9s1wn6f906w1kcjmwg9jm0000gn/T/ipykernel_4171/2110401354.py", line 2
#     sns.lineplot(data= df, x= "date", y="new_deaths")by "iso_code"
#                                                      ^
# SyntaxError: invalid syntax

# %%
val_lim=df.groupby('iso_code').mean()['new_deaths'].mean()

# %%
df.describe()
# Out:
#         total_cases      new_cases  new_cases_smoothed   total_deaths  \
# count  2.582000e+04   25780.000000        2.561500e+04   24103.000000
# mean   9.184618e+05    2659.278860        2.255902e+06   30997.708377
# std    3.151078e+06   10423.943816        8.941737e+06   90596.547701
# min    1.000000e+00       0.000000        0.000000e+00       1.000000
# 25%    4.823000e+03       1.000000        3.714000e+03     143.000000
# 50%    4.911500e+04     118.000000        8.371400e+04    1320.000000
# 75%    4.476360e+05    1007.000000        8.503575e+05   10490.500000
# max    3.088051e+07  287149.000000        1.887854e+08  666261.000000
#
#          new_deaths  new_deaths_smoothed  icu_patients  hosp_patients  \
# count  24067.000000         2.390500e+04   1812.000000     379.000000
# mean      69.188889         5.934031e+04   1593.245033     888.087071
# std      237.824205         2.062055e+05   1671.233684     630.266569
# ...

# %%
val_lim
# Out:
# 65.13868408118252

# %%
ind1 = (df.new_deaths> 69)  & (df.new_deaths < 90)
ind2 = df.new_deaths == 3

# %%
ind2
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 25963    False
# 25964    False
# 25965    False
# 25966    False
# 25967    False
# Name: new_deaths, Length: 25968, dtype: bool

# %%
df_69 = df[ind1]
df_3 = df[ind2]

# %%
plt.figure(figsize=(15,8))
sns.lineplot(data= df_69, x= "date", y="new_deaths")
# Out:
# <AxesSubplot:xlabel='date', ylabel='new_deaths'>

# %%
plt.figure(figsize=(15,8))
sns.lineplot(data= df_3, x= "date", y="new_deaths")
# Out:
# <AxesSubplot:xlabel='date', ylabel='new_deaths'>

# %%
df_3
# Out:
#       iso_code      continent             location       date  total_cases  \
# 566        ATG  North America  Antigua and Barbuda 2021-09-30       3231.0
# 568        ATG  North America  Antigua and Barbuda 2021-10-02       3403.0
# 574        ATG  North America  Antigua and Barbuda 2021-10-08       3678.0
# 593        ATG  North America  Antigua and Barbuda 2021-10-27       4036.0
# 699        ATG  North America  Antigua and Barbuda 2022-02-10       7321.0
# ...        ...            ...                  ...        ...          ...
# 25877      VEN  South America            Venezuela 2022-02-25     513427.0
# 25878      VEN  South America            Venezuela 2022-02-26     514315.0
# 25882      VEN  South America            Venezuela 2022-03-02     515582.0
# 25890      VEN  South America            Venezuela 2022-03-10     517720.0
# 25905      VEN  South America            Venezuela 2022-03-25     520038.0
#
#        new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# ...

# %%
ind_arg = (df.new_deaths > 159) & (df.iso_code == 'ARG') | (df.new_deaths > ) & (df.iso_code == 'ARG')
df['malos'] = ind_arg

# %%
df
# Out:
#       iso_code      continent             location       date  total_cases  \
# 0          ATG  North America  Antigua and Barbuda 2020-03-13          1.0
# 1          ATG  North America  Antigua and Barbuda 2020-03-14          1.0
# 2          ATG  North America  Antigua and Barbuda 2020-03-15          1.0
# 3          ATG  North America  Antigua and Barbuda 2020-03-16          1.0
# 4          ATG  North America  Antigua and Barbuda 2020-03-17          1.0
# ...        ...            ...                  ...        ...          ...
# 25963      VEN  South America            Venezuela 2022-05-22     523343.0
# 25964      VEN  South America            Venezuela 2022-05-23     523377.0
# 25965      VEN  South America            Venezuela 2022-05-24     523411.0
# 25966      VEN  South America            Venezuela 2022-05-25     523411.0
# 25967      VEN  South America            Venezuela 2022-05-26     523444.0
#
#        new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# ...

# %%
df_cloro = pd.read_excel('/Users/juan/Downloads/cloro_search.xlsx')

# %%
df_cloro['ratio'] = pd.to_numeric(df_cloro.ratio, errors='coerce')

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/3z/xmq9s1wn6f906w1kcjmwg9jm0000gn/T/ipykernel_4171/144895082.py in <module>
# ----> 1 df_cloro.sort_values('ratio')
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    6268                 ascending = ascending[0]
#    6269
# -> 6270             indexer = nargsort(
#    6271                 k, kind=kind, ascending=ascending, na_position=na_position, key=key
#    6272             )
#
# ...

# %%
df_cloro
# Out:
#           date  count  total_count     ratio
# 0   2020-03-01    0.0       2301.0  0.000000
# 1   2020-03-02    0.0       2812.0  0.000000
# 2   2020-03-03    9.0       2845.0  0.003163
# 3   2020-03-04    0.0       2953.0  0.000000
# 4   2020-03-05    0.0       2822.0  0.000000
# ..         ...    ...          ...       ...
# 839        NaT    NaN          NaN       NaN
# 840        NaT    NaN          NaN       NaN
# 841        NaT    NaN          NaN       NaN
# 842        NaT    NaN          NaN       NaN
# 843        NaT    NaN          NaN       NaN
#
# [844 rows x 4 columns]

# %%
df_col = df[df.iso_code == 'COL']
#df_col = df_col[['date', 'new_deaths']]
df_col.sort_values('date')
# Out:
#      iso_code      continent  location       date  total_cases  new_cases  \
# 6532      COL  South America  Colombia 2020-03-06          1.0        1.0
# 6533      COL  South America  Colombia 2020-03-07          1.0        0.0
# 6534      COL  South America  Colombia 2020-03-08          1.0        0.0
# 6535      COL  South America  Colombia 2020-03-09          1.0        0.0
# 6536      COL  South America  Colombia 2020-03-10          3.0        2.0
# ...       ...            ...       ...        ...          ...        ...
# 7339      COL  South America  Colombia 2022-05-22    6099111.0        0.0
# 7340      COL  South America  Colombia 2022-05-23    6099111.0        0.0
# 7341      COL  South America  Colombia 2022-05-24    6099111.0        0.0
# 7342      COL  South America  Colombia 2022-05-25    6099111.0        0.0
# 7343      COL  South America  Colombia 2022-05-26    6103455.0     4344.0
#
#       new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %%
df_combinado = df_cloro.merge(df_col, on ='date', how='left')

# %%
df_combinado.ratio.corr(df_combinado.new_deaths)
# Out:
# 0.008537516092354406

# %%
df_combinado = df_combinado [["new_deaths", "ratio",]]

# %%
plt.figure(figsize=(8,8))
sns.heatmap(df_combinado.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
a = df_combinado.("new_deaths")
b = df_combinado.("ratio")

plt.figure(figsize=(28,38))
sns.heatmap(a, annot=True)
# Out:
#   File "/var/folders/3z/xmq9s1wn6f906w1kcjmwg9jm0000gn/T/ipykernel_4171/2294108051.py", line 1
#     a = df_combinado.("new_deaths")
#                      ^
# SyntaxError: invalid syntax

# %%
plt.figure(figsize=(15,8))
sns.lineplot(data= df, x= "date", y="new_deaths")

plt.figure(figsize=(15,8))
sns.lineplot(data= df_cloro, x= "date", y="total_count")
# Out:
# <AxesSubplot:xlabel='date', ylabel='total_count'>

# %%
plt.figure(figsize=(15,8))
sns.lineplot(data= df_cloro, x= "date", y="count")
# Out:
# <AxesSubplot:xlabel='date', ylabel='count'>
